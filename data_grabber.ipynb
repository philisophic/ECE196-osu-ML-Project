# %%
import requests, json, csv, io, os
from maniera.calculator import Maniera

import time, memory_profiler, threading # for diagnostics/performance eval

# %%
## Calculate converted performance points and star (difficulty) rating for a score with given modifiers.
## Parameters:
    # h   - the score to be converted
    # mod - the score's modifiers, as a string (DT, NC, HT, 0 for none)
def mod_converter(h,mod):
    # extract relevant fields for constructing a filename
    artist = h['beatmapset']['artist']
    song = h['beatmapset']['title']
    mapper = h['beatmapset']['creator']
    difficulty = h['beatmap']['version']
    
    score = h['score'];
    
    # dictionary representing reduced bitwise enum for modifiers, see https://github.com/ppy/osu-api/wiki#mods
    modEnum = {'DT': 64, 'NC': 576, 'HT': 256, 0: 0}

    # delete leading bracket fields because they are ignored in filenames
    if (difficulty[0] == '['):
        difficulty = difficulty[difficulty.find(']') + 2:]

    # produce formatted filename
    filename = 'maps\%s - %s (%s) [%s].osu' % (artist, song, mapper, difficulty)
    filename = filename.replace('/', '').replace('?', '').replace('*', '').replace('"', '') # remove illegal filename chars

    # remove non-ASCII chars by writing to a temporary .osu file
    with io.open(filename,'r',encoding='utf-8',errors='ignore') as infile, io.open('temp.osu','w',encoding='ascii',errors='ignore') as outfile:
        for line in infile:
            print(*line.split(), file=outfile)

    # calculate new star rating and pp
    calc = Maniera('temp.osu', modEnum[mod], score)
    calc.calculate()
    
    os.remove('temp.osu') # delete temporary .osu file
    
    return round(calc.pp,2), round(calc.sr,3);

# %%
startTime = time.time();

# %%
### Retrieve token

configName = 'config.json'; # location of json file containing header params (api key, etc.)

''' create config.json in this form, put in root directory
{
    'grant_type': 'client_credentials',
    'client_id': 1,
    'client_secret': "put yours here",
    'scope': 'public'
}
'''
with open(configName) as file:
    params = json.load(file);

token = requests.post('https://osu.ppy.sh/oauth/token', params).json()['access_token']

headers = {
    'Authorization': 'Bearer ' + token
}

# %%
# id = 1815478 #me
# id = 259972 #jakads
id = 5610085 #etiennexc

url = 'https://osu.ppy.sh/api/v2/users/{}/scores/best?limit=51'.format(id) # api endpoint url

r = requests.get(url, headers = headers)

## Write data to .csv
stats = []
for h in r.json():
    if h['mods'] == []:
        temp2 = {'mods':0}
    else:
        if any(x == 'DT' for x in h['mods']) or any(x == 'NC' for x in h['mods']):
            temp2 = {'mods':'DT'}
            h['pp'], h['beatmap']['difficulty_rating'] = mod_converter(h,temp2['mods'])
            h['beatmap']['bpm'] *= 1.5
        elif any(x == 'HT' for x in h['mods']):
            temp2 = {'mods':'HT'}
            h['pp'], h['beatmap']['difficulty_rating'] = mod_converter(h,temp2['mods'])
            h['beatmap']['bpm'] *= .75
    temp3 = {'pp':h['pp']}
    temp = h['beatmap'].copy()
    temp.update(h['statistics'])
    temp.update(temp2)
    temp.update(temp3)
    for e in ['id','mode','version','ar','beatmapset_id','convert','count_spinners','cs','deleted_at','drain','is_scoreable','last_updated','mode_int','ranked','status','url']:
        temp.pop(e)
    stats.append(temp)
keys = stats[0].keys()
filename = '{}.csv'.format(id)
with open(filename, 'w', newline='')  as output_file:
    dict_writer = csv.DictWriter(output_file, keys)
    dict_writer.writeheader()
    dict_writer.writerows(stats)

# %%
stats
# Out:
# [{'difficulty_rating': 7.309,
#   'accuracy': 8.5,
#   'bpm': 262.5,
#   'count_circles': 3818,
#   'count_sliders': 35,
#   'hit_length': 319,
#   'passcount': 184316,
#   'playcount': 698531,
#   'total_length': 319,
#   'count_50': 0,
#   'count_100': 7,
#   'count_300': 640,
#   'count_geki': 3156,
#   'count_katu': 42,
#   'count_miss': 8,
#   'mods': 'DT',
#   'pp': 609.48},
#  {'difficulty_rating': 7.477,
#   'accuracy': 9,
#   'bpm': 120.0,
#   'count_circles': 1764,
#   'count_sliders': 7,
#   'hit_length': 123,
#   'passcount': 23361,
#   'playcount': 111880,
#   'total_length': 126,
#   'count_50': 5,
#   'count_100': 23,
#   'count_300': 404,
#   'count_geki': 1209,
#   'count_katu': 113,
#   'count_miss': 17,
#   'mods': 'DT',
#   'pp': 520.94},
#  {'difficulty_rating': 7.01,
#   'accuracy': 9,
#   'bpm': 256,
#   'count_circles': 2404,
#   'count_sliders': 57,
#   'hit_length': 126,
#   'passcount': 59899,
#   'playcount': 410658,
#   'total_length': 127,
#   'count_50': 2,
#   'count_100': 4,
#   'count_300': 556,
#   'count_geki': 1833,
#   'count_katu': 64,
#   'count_miss': 2,
#   'mods': 0,
#   'pp': 513.29},
#  {'difficulty_rating': 7.702,
#   'accuracy': 8.5,
#   'bpm': 292.5,
#   'count_circles': 1779,
#   'count_sliders': 34,
#   'hit_length': 110,
#   'passcount': 124390,
#   'playcount': 409342,
#   'total_length': 112,
#   'count_50': 2,
#   'count_100': 35,
#   'count_300': 536,
#   'count_geki': 1080,
#   'count_katu': 135,
#   'count_miss': 25,
#   'mods': 'DT',
#   'pp': 506.66},
#  {'difficulty_rating': 6.54,
#   'accuracy': 8,
#   'bpm': 270,
#   'count_circles': 5421,
#   'count_sliders': 470,
#   'hit_length': 402,
#   'passcount': 146458,
#   'playcount': 1095091,
#   'total_length': 402,
#   'count_50': 0,
#   'count_100': 0,
#   'count_300': 427,
#   'count_geki': 5454,
#   'count_katu': 10,
#   'count_miss': 0,
#   'mods': 0,
#   'pp': 506.318},
#  {'difficulty_rating': 6.76,
#   'accuracy': 8,
#   'bpm': 180,
#   'count_circles': 4086,
#   'count_sliders': 193,
#   'hit_length': 236,
#   'passcount': 101813,
#   'playcount': 613591,
#   'total_length': 237,
#   'count_50': 0,
#   'count_100': 4,
#   'count_300': 844,
#   'count_geki': 3353,
#   'count_katu': 73,
#   'count_miss': 5,
#   'mods': 0,
#   'pp': 489.258},
#  {'difficulty_rating': 7.068,
#   'accuracy': 8.5,
#   'bpm': 303.0,
#   'count_circles': 1753,
#   'count_sliders': 29,
#   'hit_length': 119,
#   'passcount': 142895,
#   'playcount': 448250,
#   'total_length': 121,
#   'count_50': 0,
#   'count_100': 13,
#   'count_300': 437,
#   'count_geki': 1249,
#   'count_katu': 73,
#   'count_miss': 10,
#   'mods': 'DT',
#   'pp': 483.89},
#  {'difficulty_rating': 6.703,
#   'accuracy': 7.5,
#   'bpm': 265.5,
#   'count_circles': 3333,
#   'count_sliders': 397,
#   'hit_length': 315,
#   'passcount': 54332,
#   'playcount': 415805,
#   'total_length': 316,
#   'count_50': 1,
#   'count_100': 9,
#   'count_300': 765,
#   'count_geki': 2877,
#   'count_katu': 67,
#   'count_miss': 11,
#   'mods': 'DT',
#   'pp': 460.36},
#  {'difficulty_rating': 6.621,
#   'accuracy': 8.6,
#   'bpm': 288.0,
#   'count_circles': 1932,
#   'count_sliders': 50,
#   'hit_length': 120,
#   'passcount': 22500,
#   'playcount': 95670,
#   'total_length': 122,
#   'count_50': 0,
#   'count_100': 1,
#   'count_300': 390,
#   'count_geki': 1547,
#   'count_katu': 39,
#   'count_miss': 5,
#   'mods': 'DT',
#   'pp': 447.5},
#  {'difficulty_rating': 7.016,
#   'accuracy': 8,
#   'bpm': 262.5,
#   'count_circles': 1755,
#   'count_sliders': 184,
#   'hit_length': 137,
#   'passcount': 124566,
#   'playcount': 530706,
#   'total_length': 140,
#   'count_50': 0,
#   'count_100': 23,
#   'count_300': 453,
#   'count_geki': 1403,
#   'count_katu': 44,
#   'count_miss': 16,
#   'mods': 'DT',
#   'pp': 495.78},
#  {'difficulty_rating': 6.523,
#   'accuracy': 7,
#   'bpm': 225.0,
#   'count_circles': 1228,
#   'count_sliders': 166,
#   'hit_length': 119,
#   'passcount': 80397,
#   'playcount': 185479,
#   'total_length': 124,
#   'count_50': 0,
#   'count_100': 4,
#   'count_300': 371,
#   'count_geki': 967,
#   'count_katu': 48,
#   'count_miss': 4,
#   'mods': 'DT',
#   'pp': 426.64},
#  {'difficulty_rating': 6.342,
#   'accuracy': 8,
#   'bpm': 286.5,
#   'count_circles': 1279,
#   'count_sliders': 185,
#   'hit_length': 131,
#   'passcount': 169302,
#   'playcount': 488750,
#   'total_length': 173,
#   'count_50': 0,
#   'count_100': 1,
#   'count_300': 214,
#   'count_geki': 1232,
#   'count_katu': 15,
#   'count_miss': 2,
#   'mods': 'DT',
#   'pp': 428.18},
#  {'difficulty_rating': 6.312,
#   'accuracy': 8.5,
#   'bpm': 300.0,
#   'count_circles': 1758,
#   'count_sliders': 119,
#   'hit_length': 144,
#   'passcount': 43182,
#   'playcount': 88651,
#   'total_length': 144,
#   'count_50': 1,
#   'count_100': 7,
#   'count_300': 420,
#   'count_geki': 1411,
#   'count_katu': 37,
#   'count_miss': 1,
#   'mods': 'DT',
#   'pp': 411.8},
#  {'difficulty_rating': 6.739,
#   'accuracy': 8.5,
#   'bpm': 300.0,
#   'count_circles': 1615,
#   'count_sliders': 96,
#   'hit_length': 112,
#   'passcount': 67296,
#   'playcount': 181114,
#   'total_length': 112,
#   'count_50': 1,
#   'count_100': 12,
#   'count_300': 441,
#   'count_geki': 1155,
#   'count_katu': 84,
#   'count_miss': 18,
#   'mods': 'DT',
#   'pp': 413.57},
#  {'difficulty_rating': 6.388,
#   'accuracy': 8,
#   'bpm': 294.0,
#   'count_circles': 1309,
#   'count_sliders': 93,
#   'hit_length': 111,
#   'passcount': 196849,
#   'playcount': 385988,
#   'total_length': 111,
#   'count_50': 0,
#   'count_100': 2,
#   'count_300': 289,
#   'count_geki': 1088,
#   'count_katu': 19,
#   'count_miss': 4,
#   'mods': 'DT',
#   'pp': 415.15},
#  {'difficulty_rating': 6.706,
#   'accuracy': 8.5,
#   'bpm': 307.5,
#   'count_circles': 1704,
#   'count_sliders': 136,
#   'hit_length': 119,
#   'passcount': 72587,
#   'playcount': 212345,
#   'total_length': 120,
#   'count_50': 0,
#   'count_100': 18,
#   'count_300': 538,
#   'count_geki': 1161,
#   'count_katu': 102,
#   'count_miss': 21,
#   'mods': 'DT',
#   'pp': 404.69},
#  {'difficulty_rating': 6.497,
#   'accuracy': 9,
#   'bpm': 270.0,
#   'count_circles': 3150,
#   'count_sliders': 104,
#   'hit_length': 236,
#   'passcount': 121380,
#   'playcount': 466842,
#   'total_length': 237,
#   'count_50': 1,
#   'count_100': 20,
#   'count_300': 752,
#   'count_geki': 2321,
#   'count_katu': 138,
#   'count_miss': 22,
#   'mods': 'DT',
#   'pp': 408.82},
#  {'difficulty_rating': 6.501,
#   'accuracy': 8,
#   'bpm': 232.5,
#   'count_circles': 3405,
#   'count_sliders': 306,
#   'hit_length': 307,
#   'passcount': 33062,
#   'playcount': 187128,
#   'total_length': 312,
#   'count_50': 5,
#   'count_100': 7,
#   'count_300': 721,
#   'count_geki': 2900,
#   'count_katu': 65,
#   'count_miss': 13,
#   'mods': 'DT',
#   'pp': 426.77},
#  {'difficulty_rating': 6.859,
#   'accuracy': 8.2,
#   'bpm': 300.0,
#   'count_circles': 1576,
#   'count_sliders': 161,
#   'hit_length': 114,
#   'passcount': 50391,
#   'playcount': 174686,
#   'total_length': 115,
#   'count_50': 5,
#   'count_100': 27,
#   'count_300': 578,
#   'count_geki': 1014,
#   'count_katu': 92,
#   'count_miss': 21,
#   'mods': 'DT',
#   'pp': 395.94},
#  {'difficulty_rating': 6.599,
#   'accuracy': 8,
#   'bpm': 304.5,
#   'count_circles': 1583,
#   'count_sliders': 122,
#   'hit_length': 118,
#   'passcount': 55260,
#   'playcount': 162555,
#   'total_length': 119,
#   'count_50': 4,
#   'count_100': 18,
#   'count_300': 503,
#   'count_geki': 1102,
#   'count_katu': 58,
#   'count_miss': 20,
#   'mods': 'DT',
#   'pp': 386.39},
#  {'difficulty_rating': 6.348,
#   'accuracy': 8.5,
#   'bpm': 300.0,
#   'count_circles': 2260,
#   'count_sliders': 8,
#   'hit_length': 186,
#   'passcount': 53003,
#   'playcount': 275477,
#   'total_length': 187,
#   'count_50': 0,
#   'count_100': 8,
#   'count_300': 422,
#   'count_geki': 1767,
#   'count_katu': 57,
#   'count_miss': 14,
#   'mods': 'DT',
#   'pp': 392.97},
#  {'difficulty_rating': 5.79,
#   'accuracy': 8,
#   'bpm': 300,
#   'count_circles': 1984,
#   'count_sliders': 69,
#   'hit_length': 129,
#   'passcount': 203825,
#   'playcount': 550307,
#   'total_length': 129,
#   'count_50': 0,
#   'count_100': 0,
#   'count_300': 197,
#   'count_geki': 1856,
#   'count_katu': 0,
#   'count_miss': 0,
#   'mods': 0,
#   'pp': 385.511},
#  {'difficulty_rating': 6.191,
#   'accuracy': 8.2,
#   'bpm': 285.0,
#   'count_circles': 1099,
#   'count_sliders': 189,
#   'hit_length': 111,
#   'passcount': 94610,
#   'playcount': 254140,
#   'total_length': 113,
#   'count_50': 0,
#   'count_100': 6,
#   'count_300': 292,
#   'count_geki': 964,
#   'count_katu': 21,
#   'count_miss': 5,
#   'mods': 'DT',
#   'pp': 378.2},
#  {'difficulty_rating': 6.793,
#   'accuracy': 9,
#   'bpm': 318.0,
#   'count_circles': 1484,
#   'count_sliders': 55,
#   'hit_length': 119,
#   'passcount': 50328,
#   'playcount': 183413,
#   'total_length': 120,
#   'count_50': 1,
#   'count_100': 7,
#   'count_300': 330,
#   'count_geki': 1153,
#   'count_katu': 37,
#   'count_miss': 11,
#   'mods': 'DT',
#   'pp': 462.35},
#  {'difficulty_rating': 6.319,
#   'accuracy': 8,
#   'bpm': 277.5,
#   'count_circles': 1261,
#   'count_sliders': 138,
#   'hit_length': 103,
#   'passcount': 56945,
#   'playcount': 126469,
#   'total_length': 104,
#   'count_50': 2,
#   'count_100': 9,
#   'count_300': 408,
#   'count_geki': 902,
#   'count_katu': 70,
#   'count_miss': 8,
#   'mods': 'DT',
#   'pp': 377.45},
#  {'difficulty_rating': 6.022,
#   'accuracy': 7.5,
#   'bpm': 223.5,
#   'count_circles': 1899,
#   'count_sliders': 360,
#   'hit_length': 205,
#   'passcount': 77460,
#   'playcount': 255977,
#   'total_length': 205,
#   'count_50': 4,
#   'count_100': 3,
#   'count_300': 357,
#   'count_geki': 1866,
#   'count_katu': 27,
#   'count_miss': 2,
#   'mods': 'DT',
#   'pp': 378.63},
#  {'difficulty_rating': 6.014,
#   'accuracy': 8,
#   'bpm': 276.0,
#   'count_circles': 1543,
#   'count_sliders': 66,
#   'hit_length': 120,
#   'passcount': 41970,
#   'playcount': 123053,
#   'total_length': 120,
#   'count_50': 0,
#   'count_100': 3,
#   'count_300': 365,
#   'count_geki': 1218,
#   'count_katu': 17,
#   'count_miss': 6,
#   'mods': 'DT',
#   'pp': 360.17},
#  {'difficulty_rating': 6.241,
#   'accuracy': 8.2,
#   'bpm': 384.0,
#   'count_circles': 1616,
#   'count_sliders': 35,
#   'hit_length': 126,
#   'passcount': 96667,
#   'playcount': 380104,
#   'total_length': 127,
#   'count_50': 2,
#   'count_100': 13,
#   'count_300': 478,
#   'count_geki': 1085,
#   'count_katu': 60,
#   'count_miss': 13,
#   'mods': 'DT',
#   'pp': 361.35},
#  {'difficulty_rating': 6.332,
#   'accuracy': 8,
#   'bpm': 300.0,
#   'count_circles': 1339,
#   'count_sliders': 109,
#   'hit_length': 109,
#   'passcount': 57610,
#   'playcount': 185713,
#   'total_length': 123,
#   'count_50': 4,
#   'count_100': 14,
#   'count_300': 375,
#   'count_geki': 982,
#   'count_katu': 52,
#   'count_miss': 21,
#   'mods': 'DT',
#   'pp': 356.88},
#  {'difficulty_rating': 6.065,
#   'accuracy': 8,
#   'bpm': 247.5,
#   'count_circles': 1118,
#   'count_sliders': 197,
#   'hit_length': 120,
#   'passcount': 120334,
#   'playcount': 267986,
#   'total_length': 120,
#   'count_50': 0,
#   'count_100': 6,
#   'count_300': 298,
#   'count_geki': 986,
#   'count_katu': 21,
#   'count_miss': 4,
#   'mods': 'DT',
#   'pp': 362.3},
#  {'difficulty_rating': 5.746,
#   'accuracy': 8,
#   'bpm': 261.0,
#   'count_circles': 1447,
#   'count_sliders': 79,
#   'hit_length': 116,
#   'passcount': 54836,
#   'playcount': 138277,
#   'total_length': 116,
#   'count_50': 0,
#   'count_100': 0,
#   'count_300': 186,
#   'count_geki': 1340,
#   'count_katu': 0,
#   'count_miss': 0,
#   'mods': 'DT',
#   'pp': 376.36},
#  {'difficulty_rating': 6.042,
#   'accuracy': 8,
#   'bpm': 270.0,
#   'count_circles': 2746,
#   'count_sliders': 111,
#   'hit_length': 236,
#   'passcount': 228784,
#   'playcount': 904095,
#   'total_length': 237,
#   'count_50': 1,
#   'count_100': 14,
#   'count_300': 689,
#   'count_geki': 2069,
#   'count_katu': 69,
#   'count_miss': 15,
#   'mods': 'DT',
#   'pp': 353.69},
#  {'difficulty_rating': 6.502,
#   'accuracy': 8,
#   'bpm': 318.0,
#   'count_circles': 1640,
#   'count_sliders': 28,
#   'hit_length': 123,
#   'passcount': 88881,
#   'playcount': 235813,
#   'total_length': 124,
#   'count_50': 1,
#   'count_100': 30,
#   'count_300': 454,
#   'count_geki': 1056,
#   'count_katu': 103,
#   'count_miss': 24,
#   'mods': 'DT',
#   'pp': 344.93},
#  {'difficulty_rating': 5.52,
#   'accuracy': 8.5,
#   'bpm': 270,
#   'count_circles': 2281,
#   'count_sliders': 13,
#   'hit_length': 133,
#   'passcount': 34238,
#   'playcount': 280063,
#   'total_length': 133,
#   'count_50': 0,
#   'count_100': 0,
#   'count_300': 172,
#   'count_geki': 2122,
#   'count_katu': 0,
#   'count_miss': 0,
#   'mods': 0,
#   'pp': 349.713},
#  {'difficulty_rating': 6.014,
#   'accuracy': 8.5,
#   'bpm': 300.0,
#   'count_circles': 1301,
#   'count_sliders': 69,
#   'hit_length': 116,
#   'passcount': 144877,
#   'playcount': 316416,
#   'total_length': 117,
#   'count_50': 2,
#   'count_100': 10,
#   'count_300': 333,
#   'count_geki': 975,
#   'count_katu': 44,
#   'count_miss': 6,
#   'mods': 'DT',
#   'pp': 344.08},
#  {'difficulty_rating': 5.518,
#   'accuracy': 8,
#   'bpm': 277.5,
#   'count_circles': 1511,
#   'count_sliders': 243,
#   'hit_length': 156,
#   'passcount': 62284,
#   'playcount': 163338,
#   'total_length': 159,
#   'count_50': 1,
#   'count_100': 0,
#   'count_300': 319,
#   'count_geki': 1424,
#   'count_katu': 9,
#   'count_miss': 1,
#   'mods': 'DT',
#   'pp': 327.34},
#  {'difficulty_rating': 5.849,
#   'accuracy': 8,
#   'bpm': 277.5,
#   'count_circles': 1336,
#   'count_sliders': 94,
#   'hit_length': 115,
#   'passcount': 216471,
#   'playcount': 546912,
#   'total_length': 116,
#   'count_50': 0,
#   'count_100': 5,
#   'count_300': 380,
#   'count_geki': 996,
#   'count_katu': 46,
#   'count_miss': 3,
#   'mods': 'DT',
#   'pp': 332.06},
#  {'difficulty_rating': 5.953,
#   'accuracy': 9,
#   'bpm': 280.5,
#   'count_circles': 1401,
#   'count_sliders': 21,
#   'hit_length': 101,
#   'passcount': 65187,
#   'playcount': 217237,
#   'total_length': 102,
#   'count_50': 0,
#   'count_100': 6,
#   'count_300': 305,
#   'count_geki': 1070,
#   'count_katu': 31,
#   'count_miss': 10,
#   'mods': 'DT',
#   'pp': 334.07},
#  {'difficulty_rating': 5.43,
#   'accuracy': 8,
#   'bpm': 212,
#   'count_circles': 1802,
#   'count_sliders': 112,
#   'hit_length': 119,
#   'passcount': 54624,
#   'playcount': 178397,
#   'total_length': 120,
#   'count_50': 0,
#   'count_100': 0,
#   'count_300': 233,
#   'count_geki': 1679,
#   'count_katu': 2,
#   'count_miss': 0,
#   'mods': 0,
#   'pp': 330.997},
#  {'difficulty_rating': 5.618,
#   'accuracy': 8.5,
#   'bpm': 294.0,
#   'count_circles': 1138,
#   'count_sliders': 211,
#   'hit_length': 116,
#   'passcount': 103759,
#   'playcount': 318638,
#   'total_length': 116,
#   'count_50': 0,
#   'count_100': 3,
#   'count_300': 308,
#   'count_geki': 1023,
#   'count_katu': 11,
#   'count_miss': 4,
#   'mods': 'DT',
#   'pp': 318.13},
#  {'difficulty_rating': 5.296,
#   'accuracy': 9,
#   'bpm': 220.5,
#   'count_circles': 1419,
#   'count_sliders': 26,
#   'hit_length': 109,
#   'passcount': 23054,
#   'playcount': 60599,
#   'total_length': 109,
#   'count_50': 0,
#   'count_100': 0,
#   'count_300': 155,
#   'count_geki': 1289,
#   'count_katu': 1,
#   'count_miss': 0,
#   'mods': 'DT',
#   'pp': 316.11},
#  {'difficulty_rating': 6.139,
#   'accuracy': 8,
#   'bpm': 255.0,
#   'count_circles': 1258,
#   'count_sliders': 203,
#   'hit_length': 123,
#   'passcount': 30260,
#   'playcount': 91012,
#   'total_length': 125,
#   'count_50': 4,
#   'count_100': 11,
#   'count_300': 465,
#   'count_geki': 892,
#   'count_katu': 76,
#   'count_miss': 13,
#   'mods': 'DT',
#   'pp': 332.38},
#  {'difficulty_rating': 5.773,
#   'accuracy': 9,
#   'bpm': 195.0,
#   'count_circles': 1569,
#   'count_sliders': 114,
#   'hit_length': 170,
#   'passcount': 37877,
#   'playcount': 124828,
#   'total_length': 172,
#   'count_50': 1,
#   'count_100': 7,
#   'count_300': 368,
#   'count_geki': 1266,
#   'count_katu': 34,
#   'count_miss': 7,
#   'mods': 'DT',
#   'pp': 324.79},
#  {'difficulty_rating': 5.432,
#   'accuracy': 7,
#   'bpm': 199.5,
#   'count_circles': 1557,
#   'count_sliders': 104,
#   'hit_length': 134,
#   'passcount': 64160,
#   'playcount': 151590,
#   'total_length': 138,
#   'count_50': 0,
#   'count_100': 1,
#   'count_300': 320,
#   'count_geki': 1319,
#   'count_katu': 18,
#   'count_miss': 3,
#   'mods': 'DT',
#   'pp': 308.09},
#  {'difficulty_rating': 5.59,
#   'accuracy': 8,
#   'bpm': 275.25,
#   'count_circles': 1344,
#   'count_sliders': 33,
#   'hit_length': 110,
#   'passcount': 136136,
#   'playcount': 462620,
#   'total_length': 112,
#   'count_50': 0,
#   'count_100': 5,
#   'count_300': 278,
#   'count_geki': 1069,
#   'count_katu': 18,
#   'count_miss': 7,
#   'mods': 'DT',
#   'pp': 301.62},
#  {'difficulty_rating': 5.44,
#   'accuracy': 8,
#   'bpm': 172,
#   'count_circles': 1359,
#   'count_sliders': 25,
#   'hit_length': 111,
#   'passcount': 85991,
#   'playcount': 483992,
#   'total_length': 112,
#   'count_50': 1,
#   'count_100': 1,
#   'count_300': 171,
#   'count_geki': 1190,
#   'count_katu': 20,
#   'count_miss': 1,
#   'mods': 0,
#   'pp': 305.347},
#  {'difficulty_rating': 5.607,
#   'accuracy': 9,
#   'bpm': 262.5,
#   'count_circles': 2044,
#   'count_sliders': 0,
#   'hit_length': 154,
#   'passcount': 8910,
#   'playcount': 44865,
#   'total_length': 170,
#   'count_50': 0,
#   'count_100': 1,
#   'count_300': 241,
#   'count_geki': 1754,
#   'count_katu': 34,
#   'count_miss': 14,
#   'mods': 'DT',
#   'pp': 300.36},
#  {'difficulty_rating': 5.223,
#   'accuracy': 7.5,
#   'bpm': 234.0,
#   'count_circles': 1038,
#   'count_sliders': 17,
#   'hit_length': 102,
#   'passcount': 59405,
#   'playcount': 175885,
#   'total_length': 105,
#   'count_50': 0,
#   'count_100': 0,
#   'count_300': 127,
#   'count_geki': 928,
#   'count_katu': 0,
#   'count_miss': 0,
#   'mods': 'DT',
#   'pp': 293.17},
#  {'difficulty_rating': 5.659,
#   'accuracy': 9,
#   'bpm': 225.0,
#   'count_circles': 1206,
#   'count_sliders': 30,
#   'hit_length': 134,
#   'passcount': 25417,
#   'playcount': 84583,
#   'total_length': 136,
#   'count_50': 3,
#   'count_100': 13,
#   'count_300': 291,
#   'count_geki': 880,
#   'count_katu': 41,
#   'count_miss': 8,
#   'mods': 'DT',
#   'pp': 293.81},
#  {'difficulty_rating': 5.579,
#   'accuracy': 8,
#   'bpm': 232.5,
#   'count_circles': 1291,
#   'count_sliders': 135,
#   'hit_length': 118,
#   'passcount': 29461,
#   'playcount': 112522,
#   'total_length': 120,
#   'count_50': 0,
#   'count_100': 12,
#   'count_300': 356,
#   'count_geki': 1008,
#   'count_katu': 42,
#   'count_miss': 8,
#   'mods': 'DT',
#   'pp': 292.77},
#  {'difficulty_rating': 5.05,
#   'accuracy': 8.7,
#   'bpm': 200,
#   'count_circles': 2876,
#   'count_sliders': 7,
#   'hit_length': 186,
#   'passcount': 54078,
#   'playcount': 359053,
#   'total_length': 187,
#   'count_50': 0,
#   'count_100': 0,
#   'count_300': 125,
#   'count_geki': 2758,
#   'count_katu': 0,
#   'count_miss': 0,
#   'mods': 0,
#   'pp': 288.719}]

# %%
print("Time to execute: %.4f seconds" % (time.time() - startTime))
# Out:
# Time to execute: 1.7473 seconds
